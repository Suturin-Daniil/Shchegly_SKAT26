# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
T2814 = np.loadtxt("Thrust_1180AE_7000RPM_X2814.txt")
T2220 = np.loadtxt("Thrust_1070AE_7000RPM_X2220.txt")
T2216 = np.loadtxt("Thrust_1070AE_7000RPM_X2216.txt")

Vel2814 = np.loadtxt("Vel_1180AE_7000RPM_X2814.txt")
Vel2220 = np.loadtxt("Vel_1070AE_7000RPM_X2220.txt")
Vel2216 = np.loadtxt("Vel_1070AE_7000RPM_X2216.txt")

# %%
fig, ax = plt.subplots(1,1, figsize = (8,4))
ax.plot(Vel2814, T2814, label = "X2814 11x8", color='black')
ax.plot(Vel2814, T2220, label = "X2220/16 10x7", linestyle='--', color='black')
#ax.plot(Vel2814, T2216, color='black')
ax.legend(fontsize = 12)
ax.grid("Major")
ax.vlines(18, 0, 18, linestyles='--', color = 'black')
ax.set_xlim(0,25)
ax.set_ylim(0,18)
ax.set_xlabel("$V_{a}$, м/с")
ax.set_ylabel("T, H")
# Out:
# Text(0, 0.5, 'T, H')
